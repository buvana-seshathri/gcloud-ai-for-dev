# %% [markdown]
# <a href="https://colab.research.google.com/github/buvana-seshathri/gcloud-ai-for-dev/blob/main/encoder_decoder_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import time

import numpy as np
import tensorflow as tf

# %%
filepath = tf.keras.utils.get_file("shakespeare.txt",
    "https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt",)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# 1115394/1115394 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
text = open(filepath, "rb").read().decode(encoding="utf-8")
print(f"Length of text: {len(text)} characters")
# Out:
# Length of text: 1115394 characters

# %%
print(text[:100])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You

# %%
vocab = sorted(set(text))
print("unique character count: ", len(vocab))
# Out:
# unique character count:  65

# %%
ids_from_chars = tf.keras.layers.StringLookup(
    vocabulary=list(vocab), mask_token=None
)

# %%
chars_from_ids = tf.keras.layers.StringLookup(
    vocabulary=ids_from_chars.get_vocabulary(), invert=True, mask_token=None
)

# %%
def text_from_ids(ids):
    return tf.strings.reduce_join(chars_from_ids(ids), axis=-1)

# %%
all_ids = ids_from_chars(tf.strings.unicode_split(text, "UTF-8"))
all_ids
# Out:
# <tf.Tensor: shape=(1115394,), dtype=int64, numpy=array([19, 48, 57, ..., 46,  9,  1])>

# %%
ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)

# %%
for ids in ids_dataset.take(10):
    print(chars_from_ids(ids).numpy().decode("utf-8"))
# Out:
# F
# i
# r
# s
# t
#
# C
# i
# t
# i

# %%
seq_length = 100
examples_per_epoch = len(text) // (seq_length + 1)

# %%
sequences = ids_dataset.batch(seq_length + 1, drop_remainder=True)

for seq in sequences.take(2):
    print(chars_from_ids(seq))
# Out:
# tf.Tensor(
# [b'F' b'i' b'r' b's' b't' b' ' b'C' b'i' b't' b'i' b'z' b'e' b'n' b':'
#  b'\n' b'B' b'e' b'f' b'o' b'r' b'e' b' ' b'w' b'e' b' ' b'p' b'r' b'o'
#  b'c' b'e' b'e' b'd' b' ' b'a' b'n' b'y' b' ' b'f' b'u' b'r' b't' b'h'
#  b'e' b'r' b',' b' ' b'h' b'e' b'a' b'r' b' ' b'm' b'e' b' ' b's' b'p'
#  b'e' b'a' b'k' b'.' b'\n' b'\n' b'A' b'l' b'l' b':' b'\n' b'S' b'p' b'e'
#  b'a' b'k' b',' b' ' b's' b'p' b'e' b'a' b'k' b'.' b'\n' b'\n' b'F' b'i'
#  b'r' b's' b't' b' ' b'C' b'i' b't' b'i' b'z' b'e' b'n' b':' b'\n' b'Y'
#  b'o' b'u' b' '], shape=(101,), dtype=string)
# tf.Tensor(
# [b'a' b'r' b'e' b' ' b'a' b'l' b'l' b' ' b'r' b'e' b's' b'o' b'l' b'v'
#  b'e' b'd' b' ' b'r' b'a' b't' b'h' b'e' b'r' b' ' b't' b'o' b' ' b'd'
#  b'i' b'e' b' ' b't' b'h' b'a' b'n' b' ' b't' b'o' b' ' b'f' b'a' b'm'
#  b'i' b's' b'h' b'?' b'\n' b'\n' b'A' b'l' b'l' b':' b'\n' b'R' b'e' b's'
#  b'o' b'l' b'v' b'e' b'd' b'.' b' ' b'r' b'e' b's' b'o' b'l' b'v' b'e'
#  b'd' b'.' b'\n' b'\n' b'F' b'i' b'r' b's' b't' b' ' b'C' b'i' b't' b'i'
#  b'z' b'e' b'n' b':' b'\n' b'F' b'i' b'r' b's' b't' b',' b' ' b'y' b'o'
#  b'u' b' ' b'k'], shape=(101,), dtype=string)

# %%
for seq in sequences.take(5):
    print(text_from_ids(seq).numpy())
# Out:
# b'First Citizen:\nBefore we proceed any further, hear me speak.\n\nAll:\nSpeak, speak.\n\nFirst Citizen:\nYou '
# b'are all resolved rather to die than to famish?\n\nAll:\nResolved. resolved.\n\nFirst Citizen:\nFirst, you k'
# b"now Caius Marcius is chief enemy to the people.\n\nAll:\nWe know't, we know't.\n\nFirst Citizen:\nLet us ki"
# b"ll him, and we'll have corn at our own price.\nIs't a verdict?\n\nAll:\nNo more talking on't; let it be d"
# b'one: away, away!\n\nSecond Citizen:\nOne word, good citizens.\n\nFirst Citizen:\nWe are accounted poor citi'

# %%
def split_input_target(sequence):
    input_text = sequence[:-1]
    target_text = sequence[1:]
    return input_text, target_text

# %%
split_input_target(list("Tensorflow"))
# Out:
# (['T', 'e', 'n', 's', 'o', 'r', 'f', 'l', 'o'],
#  ['e', 'n', 's', 'o', 'r', 'f', 'l', 'o', 'w'])

# %%
dataset = sequences.map(split_input_target)

# %%
for input_example, target_example in dataset.take(1):
    print("Input :", text_from_ids(input_example).numpy())
    print("Target:", text_from_ids(target_example).numpy())
# Out:
# Input : b'First Citizen:\nBefore we proceed any further, hear me speak.\n\nAll:\nSpeak, speak.\n\nFirst Citizen:\nYou'
# Target: b'irst Citizen:\nBefore we proceed any further, hear me speak.\n\nAll:\nSpeak, speak.\n\nFirst Citizen:\nYou '

# %%
# Batch size
BATCH_SIZE = 64

BUFFER_SIZE = 10000

dataset = (
    dataset.shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE, drop_remainder=True)
    .prefetch(tf.data.experimental.AUTOTUNE)
)

dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(64, 100), dtype=tf.int64, name=None), TensorSpec(shape=(64, 100), dtype=tf.int64, name=None))>

# %%
# Length of the vocabulary in chars
vocab_size = len(vocab)

# The embedding dimension - size of vector we want to represent our characters with
embedding_dim = 256

# Number of RNN units - no of neurons
rnn_units = 1024

# %%
class MyModel(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, rnn_units):
        super().__init__()
        # TODO - Create an embedding layer
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        # TODO - Create a GRU layer
        self.gru = tf.keras.layers.GRU(
            rnn_units, return_sequences=True, return_state=True
        )
        # TODO - Finally connect it with a dense layer
        self.dense = tf.keras.layers.Dense(vocab_size)

    def call(self, inputs, states=None, return_state=False, training=False):
        x = self.embedding(inputs, training=training)
        # Pass states directly to the GRU layer. If states is None,
        # the GRU layer will initialize a zero state internally.
        x, states = self.gru(x, initial_state=states, training=training)
        x = self.dense(x, training=training)

        if return_state:
            return x, states
        else:
            return x

# %%
model = MyModel(
    # Be sure the vocabulary size matches the `StringLookup` layers.
    vocab_size=len(ids_from_chars.get_vocabulary()),
    embedding_dim=embedding_dim,
    rnn_units=rnn_units,
)

# %%
for input_example_batch, target_example_batch in dataset.take(1):
    example_batch_predictions = model(input_example_batch)
    print(
        example_batch_predictions.shape,
        "# (batch_size, sequence_length, vocab_size)",
    )
# Out:
# (64, 100, 66) # (batch_size, sequence_length, vocab_size)

# %%
model.summary()
# Out:
# Model: "my_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (64, 100, 256)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ ((64, 100, 1024), (64, │     3,938,304 │
# │                                 │ 1024))                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (64, 100, 66)          │        67,650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,022,850 (15.35 MB)
#  Trainable params: 4,022,850 (15.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
sampled_indices = tf.random.categorical(
    example_batch_predictions[0], num_samples=1
)
sampled_indices = tf.squeeze(sampled_indices, axis=-1).numpy()

# %%
sampled_indices
# Out:
# array([ 1,  4, 53,  9, 48, 49,  2, 65,  7, 25, 11, 20, 42, 45, 21, 15,  5,
#         6, 40,  8, 60,  7,  9,  7, 13, 16,  3,  5, 31, 58, 46, 64, 10, 44,
#        28, 11, 28, 27, 52,  5, 19, 41, 34, 53, 50, 48, 57, 17, 47,  4, 22,
#        18, 18, 32, 50, 37, 25,  2, 24, 28, 21, 38,  4, 13, 10,  4, 10, 56,
#        54, 36, 15, 24, 21, 23,  2, 27, 13, 53, 59, 63, 42,  0, 21, 49,  6,
#        29, 28, 14, 39, 52, 38, 17,  2, 18, 45, 34, 20, 32,  6, 48])

# %%
print("Input:\n", text_from_ids(input_example_batch[0]).numpy())
print()
print("Next Char Predictions:\n", text_from_ids(sampled_indices).numpy())
# Out:
# Input:
#  b"\n'Tis well; and I have met a gentleman\nHath promised me to help me to another,\nA fine musician to in"
#
# Next Char Predictions:
#  b"\n$n.ij z,L:GcfHB&'a-u,.,?C!&Rsgy3eO:ONm&FbUnkirDh$IEESkXL KOHY$?3$3qoWBKHJ N?ntxc[UNK]Hj'POAZmYD EfUGS'i"

# %%
loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
example_batch_mean_loss = loss(target_example_batch, example_batch_predictions)
print(
    "Prediction shape: ",
    example_batch_predictions.shape,
    " # (batch_size, sequence_length, vocab_size)",
)
print("Mean loss:        ", example_batch_mean_loss)
# Out:
# Prediction shape:  (64, 100, 66)  # (batch_size, sequence_length, vocab_size)
# Mean loss:         tf.Tensor(4.188641, shape=(), dtype=float32)

# %%
tf.exp(example_batch_mean_loss).numpy()
# Out:
# np.float32(65.933136)

# %%
model.compile(optimizer="adam", loss=loss)

# %%
# Directory where the checkpoints will be saved
checkpoint_dir = "./training_checkpoints"
# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}.weights.h5")

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix, save_weights_only=True
)

# %%
EPOCHS = 30

# %%
history = model.fit(dataset, epochs=EPOCHS, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.1238
# Epoch 2/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.0813
# Epoch 3/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.0368
# Epoch 4/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.9906
# Epoch 5/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.9433
# Epoch 6/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.8934
# Epoch 7/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.8440
# Epoch 8/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.7956
# Epoch 9/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.7488
# Epoch 10/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.7045
# Epoch 11/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.6644
# Epoch 12/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.6269
# Epoch 13/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.5958
# Epoch 14/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.5680
# Epoch 15/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.5440
# Epoch 16/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.5280
# Epoch 17/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.5143
# Epoch 18/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4975
# Epoch 19/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4835
# Epoch 20/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.4748
# Epoch 21/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.4709
# Epoch 22/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4646
# Epoch 23/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4617
# Epoch 24/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4570
# Epoch 25/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4537
# Epoch 26/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4540
# Epoch 27/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4498
# Epoch 28/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4493
# Epoch 29/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4525
# Epoch 30/30
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.4530

# %%
class OneStep(tf.keras.Model):
    def __init__(self, model, chars_from_ids, ids_from_chars, temperature=1.0):
        super().__init__()
        self.temperature = temperature
        self.model = model
        self.chars_from_ids = chars_from_ids
        self.ids_from_chars = ids_from_chars

        # Create a mask to prevent "[UNK]" from being generated.
        skip_ids = self.ids_from_chars(["[UNK]"])[:, None]
        sparse_mask = tf.SparseTensor(
            # Put a -inf at each bad index.
            values=[-float("inf")] * len(skip_ids),
            indices=skip_ids,
            # Match the shape to the vocabulary
            dense_shape=[len(ids_from_chars.get_vocabulary())],
        )
        self.prediction_mask = tf.sparse.to_dense(sparse_mask)

    @tf.function
    def generate_one_step(self, inputs, states=None):
        # Convert strings to token IDs.
        input_chars = tf.strings.unicode_split(inputs, "UTF-8")
        input_ids = self.ids_from_chars(input_chars).to_tensor()

        # Run the model.
        # predicted_logits.shape is [batch, char, next_char_logits]
        predicted_logits, states = self.model(
            inputs=input_ids, states=states, return_state=True
        )
        # Only use the last prediction.
        predicted_logits = predicted_logits[:, -1, :]
        predicted_logits = predicted_logits / self.temperature
        # Apply the prediction mask: prevent "[UNK]" from being generated.
        predicted_logits = predicted_logits + self.prediction_mask

        # Sample the output logits to generate token IDs.
        predicted_ids = tf.random.categorical(predicted_logits, num_samples=1)
        predicted_ids = tf.squeeze(predicted_ids, axis=-1)

        # Convert from token ids to characters
        predicted_chars = self.chars_from_ids(predicted_ids)

        # Return the characters and model state.
        return predicted_chars, states

# %%
one_step_model = OneStep(model, chars_from_ids, ids_from_chars)

# %%
start = time.time()
states = None
next_char = tf.constant(["ROMEO:"])
result = [next_char]

for n in range(1000):
    next_char, states = one_step_model.generate_one_step(
        next_char, states=states
    )
    result.append(next_char)

result = tf.strings.join(result)
end = time.time()
print(result[0].numpy().decode("utf-8"), "\n\n" + "_" * 80)
print("\nRun time:", end - start)
# Out:
# ROMEO:
# These four will mother should so pettity
# 'Tis so: for your better cannot brow
# Then vail your ignorance, if there be drowning
# That rebelo!' I were God befall'n;
# And I would have stood to end,
# Yet neat the act or't.
#
# First Lady:
# Clarence close, you show you are to make his pointed.
#
# FRIAR LAURENCE:
# Sir, here comes a man; and, going affecians bark absolute
# As what within the king and thou didst beg.
#
# Keepereor:
# Let me entreat you.
#
# BENVOLIO:
# I pray thee, feeling.
# Speak o' the fowl! why have care hence!
# For God's sake, lady, oak not Marcius, and
# What they have paid for landers lives.
#
# LEONTES:
# Shall need no more.
#
# Third Citizen:
# Before the foes that sees in murders for thee
# And most of our immortal blessmend.
#
# DERBY:
# I cannot tell: there's not a smilerbath'd sour.
#
# HASTINGS:
# No inetory, sir: I have not dismish'd
# To think it will. What sir, a sail! that
# love he be authorely now
# That would be glad to weed I stay, if they
# account of women witchy woo.
# Banished, how must he not so?
# Our titues
#
# ________________________________________________________________________________
#
# Run time: 1.5974817276000977

# %%
start = time.time()
states = None
next_char = tf.constant(["ROMEO:", "ROMEO:", "ROMEO:", "ROMEO:", "ROMEO:"])
result = [next_char]

for n in range(1000):
    next_char, states = one_step_model.generate_one_step(
        next_char, states=states
    )
    result.append(next_char)

result = tf.strings.join(result)
end = time.time()
for s in result:
    print(s.numpy().decode("utf-8"))
print("\n\n" + "_" * 80)
print("\nRun time:", end - start)
# Out:
# ROMEO:
# Thou fortune to them golden window then endorch his power.
#
# WARWICK:
# Oxford, how now! what's the neck?
#
# Servant:
# Up.
#
# ROMEO:
# Petruchio, go thy ways; though it esteen a
# renown in rose and the law untitured lose.
# What stay him I will not be king?
#
# DUKE OF YORK:
# My lords, let it o'er his comperent in
# Vienna bent, good night! knee lift delights;
# And cannot for his gracious uncle Clarence,
# Till thou repossess the spector of his light,
# Both forbids the Duke of Gluck Freyzy, at the loanth
# Of both is base and lost alone.
#
# Nurse:
# May not I tell thee poison.
#
# Third Watchman:
# By this all, or I'll kill the honour of my long.
#
# LADY ANNE:
# How far is it, my lord, this very tide.
# Come, my friends; we will undeed, get thee in them;
# And shall the sacrifing Warwick for
# the storment before that tond:
# The fouler grace me from the earth and thy bed.
#
# MIRANDA:
# I pray now, change it the queen these are:
# The city go in Gentleman, the physic
#
# ATH:
# Both mine, by Standal, free, royally require,
# Young puyes of my
# ROMEO:
# Thus only coow.
#
# RATCLIFF:
# No matter: set me up and make thee now.
#
# Servant:
# My lord, you not direct stay you look on sin,
# For me, i' my dear son of his that worth against
# A thoughts of piproach a quiet claff against
# My grained ass again with little queen.
# If it be noble monument, but that I do
# House up thy fom wholesome methon, whom lie. I
# am put a serious crown at our maid hath twenty
# Henry that the fail becoming him.
#
# KING HENRY VI:
# And since at thee, brave day for Christ: but for deceit,
# And not my warring of my kinsmen:
# I am not fooler, but to safe upon the man.
#
# BIANCA:
# Now my thousands spoke to do him with Caliban
# And yet his noble country from them take
# Their notion of their sort not prosperous:
# By this in Mantua, wes merry oaths;
# It is the king prince what thou command,
# Which to defend his present too rash read the Duke
# of Hercule 'shumber with her breath.
#
# Third Servingman:
# What, will you do the grievous stir?
#
# PUTRANCA:
# You have done a torth in peace a pay.
#
# BRAKENBURY:
# Adw
# ROMEO:
# Thus both pardon to the court.
#
# HENRY BOLINGBROKE:
# Harry of Hereford, Lancaster and Derby,
# 'Tis very tree, there are my hell have goads,
# And sit on 'tis a shower whom they not wakened.
# But what art thou, in convey? bring it me.
#
# GRUMIO:
# Have died?
#
# JULIET:
# How now, I pray? friar, thou dost infect my back,
# The rashning steal 'jagued bit and name to't,
# And with hardy as the Capulets: discrettle
# His rest, in safety nurse, or wed crafts,
# Since fough upon it ask in Lamialate
# And hanged into his own arms of guilest,
# And stand upon the chine; that is not,
# Glods may never troney?
#
# TRANIO:
# Away! the rest is not a crown'd cold and
# That thou return now: how it goes with me?
#
# BIANCA:
# A mercy! fie, die them something home.
#
# COMINIUS:
# Come hither, Marcius,
# Their marriage serve, falling spoke to his death.
# Give him death! for she is state the lie-unales,
# Naped yielded upon my kindred, fray'll quite rotten,
# Were to content them; in the morning should
# make rather to his mouth, and with five wants but
# ROMEO:
# The king! do you know the cause?
#
# ALONSO:
# I can tell you.
#
# MOPSA:
# We are, go fit thence, sir.
#
# VALER:
# I speak to death, and so I fear;
# For in all not exact is with show'd up at his face
# To effect the multher block to Richard:'
# And even here begot me in her beauty;
# Thine empluismemian statue's mouth,
# Which I'll och Tybalt's bray, would not weep,
# By heaven and noble estimation break,
# As ted out to conjure thee in his hand.
#
# HENRY BOLINGBROKE:
# In brief, to let your mother conceive,
# Long a pot of mischance to me with you; with
# Petruchion shall find thus rush'd.
# Low, we will, my mother, with this strength sir.
#
# JULIET:
# O thou, it would be thus do no more direst cat place;
# While-times of woman's life, that false personaly
# power, you proud. How do you for sack which,
# Right grandam on a king, that let Some hands
# That runs are they out to say that which in his son
# Whom they had slipp'd our nightin and me;
# But he, my son Lord Angelo kill their deaths,
# But make the law had well to do him with th
# ROMEO:
# Thou dost fall time worms and soon
# Unto the sovereign, whom thou swear'st,
# Thou art dick, nor that I meant, if he may say:
# 'IChard, like a scolding reverend court
# And little finger, there to come with tears:
# Noble Clarence, think not the place of it:
# Unveirs the chapless cause to meet my meat
# Time for my thankful seat of heaven so cure thine one,
# And see how you can winner than those that France.
# Speakers, Sir Romeo, that he shall die forth
# to put the cause of this world.
#
# DUKE VINCENTIO:
# He hath the store of out and spidity;
# And, when he knew, one Lancaster?
#
# MENENIUS:
# I'll keep you confound the found to me with better hate,
# Unless than Tyribling and dissleved as
# Controll'd that way unto the quarrel of the house
# Of all the doors at once in true denies;
# Which, by glad of my pomp, but love I need it light.
#
# HENRY PERCY:
# There are the earth to stand and crack to slaughter thee.
#
# JULIET:
# What villain you are, and see him so?
#
# BUCKINGHAM:
#
# First Citizen:
# Better do not fallen upon a soldie
#
#
# ________________________________________________________________________________
#
# Run time: 1.8635082244873047

# %%
tf.saved_model.save(one_step_model, "one_step")
one_step_reloaded = tf.saved_model.load("one_step")

# %%
states = None
next_char = tf.constant(["ROMEO:"])
result = [next_char]

for n in range(100):
    next_char, states = one_step_reloaded.generate_one_step(
        next_char, states=states
    )
    result.append(next_char)

print(tf.strings.join(result)[0].numpy().decode("utf-8"))
# Out:
# ROMEO:
# The king's, so barilling too much,
# That his beloved, so begins to me;
# And, grief, my daughter, will

# %%
class CustomTraining(MyModel):
    @tf.function
    def train_step(self, inputs):
        inputs, labels = inputs
        with tf.GradientTape() as tape:
            predictions = self(inputs, training=True)
            loss = self.loss(labels, predictions)
        grads = tape.gradient(loss, model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, model.trainable_variables))

        return {"loss": loss}

# %%
model = CustomTraining(
    vocab_size=len(ids_from_chars.get_vocabulary()),
    embedding_dim=embedding_dim,
    rnn_units=rnn_units,
)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
)

# %%
model.fit(dataset, epochs=1)
# Out:
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0000e+00

# %%
EPOCHS = 30

mean = tf.keras.metrics.Mean()

for epoch in range(EPOCHS):
    start = time.time()

    mean.reset_states()
    for batch_n, (inp, target) in enumerate(dataset):
        logs = model.train_step([inp, target])
        mean.update_state(logs["loss"])

        if batch_n % 50 == 0:
            template = (
                f"Epoch {epoch+1} Batch {batch_n} Loss {logs['loss']:.4f}"
            )
            print(template)

    # saving (checkpoint) the model every 5 epochs
    if (epoch + 1) % 5 == 0:
        model.save_weights(checkpoint_prefix.format(epoch=epoch))

    print()
    print(f"Epoch {epoch+1} Loss: {mean.result().numpy():.4f}")
    print(f"Time taken for 1 epoch {time.time() - start:.2f} sec")
    print("_", 80)

model.save_weights(checkpoint_prefix.format(epoch=epoch))
# Out:
# Epoch 1 Batch 0 Loss 2.0081
# Epoch 1 Batch 50 Loss 1.8900
# Epoch 1 Batch 100 Loss 1.8108
# Epoch 1 Batch 150 Loss 1.7125
#
# Epoch 1 Loss: 1.8331
# Time taken for 1 epoch 3.37 sec
# _ 80
# Epoch 2 Batch 0 Loss 1.6498
# Epoch 2 Batch 50 Loss 1.6229
# Epoch 2 Batch 100 Loss 1.6332
# Epoch 2 Batch 150 Loss 1.5112
#
# Epoch 2 Loss: 1.5903
# Time taken for 1 epoch 2.85 sec
# _ 80
# Epoch 3 Batch 0 Loss 1.5208
# Epoch 3 Batch 50 Loss 1.5005
# Epoch 3 Batch 100 Loss 1.4458
# Epoch 3 Batch 150 Loss 1.4308
#
# Epoch 3 Loss: 1.4644
# Time taken for 1 epoch 2.83 sec
# _ 80
# Epoch 4 Batch 0 Loss 1.4271
# Epoch 4 Batch 50 Loss 1.4063
# Epoch 4 Batch 100 Loss 1.3587
# Epoch 4 Batch 150 Loss 1.4047
#
# Epoch 4 Loss: 1.3882
# Time taken for 1 epoch 2.85 sec
# _ 80
# Epoch 5 Batch 0 Loss 1.3310
# Epoch 5 Batch 50 Loss 1.3140
# Epoch 5 Batch 100 Loss 1.3004
# Epoch 5 Batch 150 Loss 1.3304
#
# Epoch 5 Loss: 1.3334
# Time taken for 1 epoch 2.91 sec
# _ 80
# Epoch 6 Batch 0 Loss 1.2518
# Epoch 6 Batch 50 Loss 1.2844
# Epoch 6 Batch 100 Loss 1.3044
# Epoch 6 Batch 150 Loss 1.2948
#
# Epoch 6 Loss: 1.2868
# Time taken for 1 epoch 2.69 sec
# _ 80
# Epoch 7 Batch 0 Loss 1.2338
# Epoch 7 Batch 50 Loss 1.2621
# Epoch 7 Batch 100 Loss 1.2213
# Epoch 7 Batch 150 Loss 1.2415
#
# Epoch 7 Loss: 1.2459
# Time taken for 1 epoch 2.73 sec
# _ 80
# Epoch 8 Batch 0 Loss 1.1699
# Epoch 8 Batch 50 Loss 1.1896
# Epoch 8 Batch 100 Loss 1.2142
# Epoch 8 Batch 150 Loss 1.2145
#
# Epoch 8 Loss: 1.2077
# Time taken for 1 epoch 2.64 sec
# _ 80
# Epoch 9 Batch 0 Loss 1.1702
# Epoch 9 Batch 50 Loss 1.1849
# Epoch 9 Batch 100 Loss 1.1604
# Epoch 9 Batch 150 Loss 1.1708
#
# Epoch 9 Loss: 1.1698
# Time taken for 1 epoch 2.87 sec
# _ 80
# Epoch 10 Batch 0 Loss 1.1218
# Epoch 10 Batch 50 Loss 1.0934
# Epoch 10 Batch 100 Loss 1.1533
# Epoch 10 Batch 150 Loss 1.1393
#
# Epoch 10 Loss: 1.1299
# Time taken for 1 epoch 2.75 sec
# _ 80
# Epoch 11 Batch 0 Loss 1.0476
# Epoch 11 Batch 50 Loss 1.0446
# Epoch 11 Batch 100 Loss 1.1177
# Epoch 11 Batch 150 Loss 1.1004
#
# Epoch 11 Loss: 1.0900
# Time taken for 1 epoch 2.94 sec
# _ 80
# Epoch 12 Batch 0 Loss 1.0260
# Epoch 12 Batch 50 Loss 1.0635
# Epoch 12 Batch 100 Loss 1.0524
# Epoch 12 Batch 150 Loss 1.0526
#
# Epoch 12 Loss: 1.0485
# Time taken for 1 epoch 2.83 sec
# _ 80
# Epoch 13 Batch 0 Loss 1.0275
# Epoch 13 Batch 50 Loss 0.9833
# Epoch 13 Batch 100 Loss 1.0155
# Epoch 13 Batch 150 Loss 1.0049
#
# Epoch 13 Loss: 1.0030
# Time taken for 1 epoch 2.68 sec
# _ 80
# Epoch 14 Batch 0 Loss 0.9064
# Epoch 14 Batch 50 Loss 0.9661
# Epoch 14 Batch 100 Loss 0.9615
# Epoch 14 Batch 150 Loss 0.9645
#
# Epoch 14 Loss: 0.9563
# Time taken for 1 epoch 2.66 sec
# _ 80
# Epoch 15 Batch 0 Loss 0.8459
# Epoch 15 Batch 50 Loss 0.9066
# Epoch 15 Batch 100 Loss 0.9354
# Epoch 15 Batch 150 Loss 0.9459
#
# Epoch 15 Loss: 0.9102
# Time taken for 1 epoch 2.83 sec
# _ 80
# Epoch 16 Batch 0 Loss 0.8394
# Epoch 16 Batch 50 Loss 0.8594
# Epoch 16 Batch 100 Loss 0.8904
# Epoch 16 Batch 150 Loss 0.8955
#
# Epoch 16 Loss: 0.8629
# Time taken for 1 epoch 2.91 sec
# _ 80
# Epoch 17 Batch 0 Loss 0.7779
# Epoch 17 Batch 50 Loss 0.7791
# Epoch 17 Batch 100 Loss 0.8326
# Epoch 17 Batch 150 Loss 0.8483
#
# Epoch 17 Loss: 0.8134
# Time taken for 1 epoch 2.66 sec
# _ 80
# Epoch 18 Batch 0 Loss 0.7231
# Epoch 18 Batch 50 Loss 0.7488
# Epoch 18 Batch 100 Loss 0.7744
# Epoch 18 Batch 150 Loss 0.8060
#
# Epoch 18 Loss: 0.7671
# Time taken for 1 epoch 2.65 sec
# _ 80
# Epoch 19 Batch 0 Loss 0.6758
# Epoch 19 Batch 50 Loss 0.7013
# Epoch 19 Batch 100 Loss 0.7424
# Epoch 19 Batch 150 Loss 0.7554
#
# Epoch 19 Loss: 0.7219
# Time taken for 1 epoch 2.67 sec
# _ 80
# Epoch 20 Batch 0 Loss 0.6535
# Epoch 20 Batch 50 Loss 0.6330
# Epoch 20 Batch 100 Loss 0.7042
# Epoch 20 Batch 150 Loss 0.7128
#
# Epoch 20 Loss: 0.6832
# Time taken for 1 epoch 3.01 sec
# _ 80
# Epoch 21 Batch 0 Loss 0.6145
# Epoch 21 Batch 50 Loss 0.6131
# Epoch 21 Batch 100 Loss 0.6562
# Epoch 21 Batch 150 Loss 0.6750
#
# Epoch 21 Loss: 0.6460
# Time taken for 1 epoch 2.84 sec
# _ 80
# Epoch 22 Batch 0 Loss 0.5654
# Epoch 22 Batch 50 Loss 0.5846
# Epoch 22 Batch 100 Loss 0.6365
# Epoch 22 Batch 150 Loss 0.6570
#
# Epoch 22 Loss: 0.6134
# Time taken for 1 epoch 2.86 sec
# _ 80
# Epoch 23 Batch 0 Loss 0.5262
# Epoch 23 Batch 50 Loss 0.5564
# Epoch 23 Batch 100 Loss 0.6011
# Epoch 23 Batch 150 Loss 0.6373
#
# Epoch 23 Loss: 0.5835
# Time taken for 1 epoch 2.72 sec
# _ 80
# Epoch 24 Batch 0 Loss 0.5152
# Epoch 24 Batch 50 Loss 0.5339
# Epoch 24 Batch 100 Loss 0.5832
# Epoch 24 Batch 150 Loss 0.6068
#
# Epoch 24 Loss: 0.5603
# Time taken for 1 epoch 2.73 sec
# _ 80
# Epoch 25 Batch 0 Loss 0.4764
# Epoch 25 Batch 50 Loss 0.5079
# Epoch 25 Batch 100 Loss 0.5448
# Epoch 25 Batch 150 Loss 0.5864
#
# Epoch 25 Loss: 0.5400
# Time taken for 1 epoch 2.76 sec
# _ 80
# Epoch 26 Batch 0 Loss 0.4833
# Epoch 26 Batch 50 Loss 0.5051
# Epoch 26 Batch 100 Loss 0.5218
# Epoch 26 Batch 150 Loss 0.5747
#
# Epoch 26 Loss: 0.5228
# Time taken for 1 epoch 2.65 sec
# _ 80
# Epoch 27 Batch 0 Loss 0.4692
# Epoch 27 Batch 50 Loss 0.4903
# Epoch 27 Batch 100 Loss 0.5215
# Epoch 27 Batch 150 Loss 0.5596
#
# Epoch 27 Loss: 0.5119
# Time taken for 1 epoch 2.78 sec
# _ 80
# Epoch 28 Batch 0 Loss 0.4547
# Epoch 28 Batch 50 Loss 0.4682
# Epoch 28 Batch 100 Loss 0.5234
# Epoch 28 Batch 150 Loss 0.5485
#
# Epoch 28 Loss: 0.4988
# Time taken for 1 epoch 2.82 sec
# _ 80
# Epoch 29 Batch 0 Loss 0.4465
# Epoch 29 Batch 50 Loss 0.4538
# Epoch 29 Batch 100 Loss 0.4926
# Epoch 29 Batch 150 Loss 0.5197
#
# Epoch 29 Loss: 0.4887
# Time taken for 1 epoch 2.76 sec
# _ 80
# Epoch 30 Batch 0 Loss 0.4284
# Epoch 30 Batch 50 Loss 0.4556
# Epoch 30 Batch 100 Loss 0.4817
# Epoch 30 Batch 150 Loss 0.5388
#
# Epoch 30 Loss: 0.4812
# Time taken for 1 epoch 2.85 sec
# _ 80

# %%
one_step_model = OneStep(model, chars_from_ids, ids_from_chars)

# %%
start = time.time()
states = None
next_char = tf.constant(["ROMEO:", "ROMEO:", "ROMEO:", "ROMEO:", "ROMEO:"])
result = [next_char]

for n in range(1000):
    next_char, states = one_step_model.generate_one_step(
        next_char, states=states
    )
    result.append(next_char)

result = tf.strings.join(result)
end = time.time()
for s in result:
    print(s.numpy().decode("utf-8"))
print("\n\n" + "_" * 80)
print("\nRun time:", end - start)
# Out:
# ROMEO:
# The underetorable rap with king?
#
# GLOUCESTER:
# Here both in full of winest;
# Since if I see no fear? Now, keep your hate,
# But as it were, having no more than mercy
# I' the bill my followers in some bold,
# Unto the world that cannot weed me at the other.
# Thou hast been so, or she must bear?
#
# MENENIUS:
# Has he did call him for the gold, homicive,
# The fresh creature and the benefit his deep
# Sin enough: thou art a traitor
# And said 'Ay he's your highness' say home:
# These eyes shall reason the king;
# But whether here see most of all, things corn,
# I do peremptory I am no male.
# This was my speech, and I must yield confess:
# A messenger,
# That couched every cross of those.
#
# CAMILLO:
# Ay, my good friends; which thou shalt heart.
# Stand fast, he counts like one thing of
# Plants on my hands, here in the villany.
#
# GLOUCESTER:
#
# KING EDWARD IV:
# Why, so: now we be of his mother?
#
# JOHN OF GAUNT:
# God in her name, hath that, if he drew sleep.
#
# ROMEO:
# Lady, you go to? Hast thou not any welcome.
#
# SICINIUS:
# Hold, you
# ROMEO:
# Out-glassed me! I am half so much.
#
# ROMEO:
# Some say the largesser? one dest to fight with nothing
# shall be: Romeo slain my soul!
# O, indeed, sir! here comes the rage of that news?
# Or shall I see more scrutch for my mother, mother
# Is falling up with constant wash with you.
#
# ARIEL:
# No, sir, none.
#
# AUFIDIUS:
# No more even must with her
# To tell us whether their own reason. I am proof again
# Than Justice. I'll to him.
# There is my father, with a month as great
# As when a man's wild roomsted that they
# Welcome's him; fie, his heir and prayer
# My days thou couchsafe more to me unknown here?
#
# GLOUCESTER:
# But to the next monstrock, say I!
# The fire or false friends of her, for prophecy
# As that was noined more grief cannot welcome ever
# PErricken to dear execution,
# Nake in the Duke of Exeter, fire; o'erle we
# she many own him he'll say he.
#
# CORIOLANUS:
# Nay, neither my shadow and Clarence to be heard,
# Even in the leck, chy measure me;
# And therefore heavens be ready and tears.
# Away, the Volsces have pretty
# ROMEO:
# I do injury.
#
# HENRY BOLINGBROKE:
# Say there be corn-like eyes there.
#
# BUCKINGHAM:
# You have no cause to chide the root in all.
# But this my seat is Enclas-pine oble in.
#
# KING EDWARD IV:
# 'Twere pity they's meet and true beauty first,
# And therefore law shall Forthwife wares,
# Saint all the pace of name, Shaff'd and sulders;
# They with the scorn of Bushy, husting each other's
# mind of you; he is of late needs must I spill, and still
# Young, soleties 'twixt your hungry
# by her spear of bed, and steal poor brine;
# And there the arm uphorn'd Aufidius shows!
# Thou shalt be spoke of, and a post-horse: but I cannot
# much more than thus the causes. There not to us roted
# I' the border'd with the city;
# Which thou canst yield a moging horse ta'en of him.
#
# KING HENRY VI:
# This is thy peace.
#
# MARIANA:
# Gremio, 'tis not for Rome, i' God's wise:
# If you are but reason's name is made.
#
# GREMIO:
# Here's madam.
#
# VARCISTA:
# In countrymen are too soon, as you have given aly eyes
# Of my dust and sworn or amends.
#
# MENENIUS:
# I
# ROMEO:
# The encounter of my Rome hath broke
# And loving farewell of our own demand.
#
# COMINIUS:
# O, ay, frow
# raged with that his death; my father sits himself,
# No henciful tradicious,
# Which I have to put up all in seds
# contrate them.
#
# FRIAR PETER:
# Well, sir; where I may come; thou hast not so,
# Shall you be grained away; for I
# have poison's nought to slay that blind coward,
# He should it the forfeits of my suit: if thy death
# As they can she deliver to make his frait,
# And come not for Bohemia there and the lody
# On my suit: if you be must be,
# Scorn and I cannot, be it known to us
# And in the second cap of which charms and like
# As everlacted scorn, and one that knows
# What is no sleep? step indeed that quarrel?
#
# DUKE VINCENTIO:
# No. Hark!
# We may surprise at unacate a fair
# As you'll disperited before a woman.
#
# CATESBY:
# The greatest free, did scarce those bliss
# and their guards that were the bowest advertities
# My in my hand and syrand some justice,
# If you to God 'pardon' far off such a cock
# To ply the roy
# ROMEO:
# O, were it but just office, let us lie all flay;
# Thou shalt be whipt of enter; these all unjust,
# And stack of prime of mathous world excuse thy death.
# 3 KING HENRY VI
#
# CLIFFORD:
# Fly, with that name, that you shall succor him;
# And leave not of him.
#
# MENENIUS:
# One thing that is more ten thousand on some other
# flink for hate, yea, our will be tutorion
# Call to your suckings and open
# The greatest froe departing high with art
# From Time Harriage, with a far of works,
# Shall keep his timeless cries of his love
# Under the desperate cowardom of this isle,
# Having spectation of her wombs.
# Speak not on that pardom, Dare on being proud,
# Which, title out upon 't.
#
# PAULINA:
# Good good Lady, Margaret;
# This weak arms dearer; uncharged and said
# That 'grius, we'll succeed all thy breast!
# Yet if the time when most great would do live
# But to the rostly of thy sovereign speedix'd
# Rome seeming so in heavenly pays do spite our love,
# And chame too longers; though the matter died,
# But changing every necess to chea
#
#
# ________________________________________________________________________________
#
# Run time: 1.862537145614624
